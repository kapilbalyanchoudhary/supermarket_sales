# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("supermarket_sales new.csv")
df
# Out:
#      Gender   Invoice ID Branch       City Customer type  \
# 0    Female  750-67-8428      A     Yangon        Member
# 1    Female  226-31-3081      C  Naypyitaw        Normal
# 2    Female  355-53-5943      A     Yangon        Member
# 3    Female  315-22-5665      C  Naypyitaw        Normal
# 4    Female  665-32-9167      A     Yangon        Member
# ..      ...          ...    ...        ...           ...
# 995    Male  745-74-0715      A     Yangon        Normal
# 996    Male  690-01-6631      B   Mandalay        Normal
# 997    Male  233-67-5758      C  Naypyitaw        Normal
# 998    Male  727-02-1313      A     Yangon        Member
# 999    Male  347-56-2442      A     Yangon        Normal
#
#                Product line  Unit price  Quantity    Tax 5%
# 0         Health and beauty       74.69         7  261.4150
# 1    Electronic accessories       15.28         5    3.8200
# 2    Electronic accessories       68.84         6   20.6520
# 3        Home and lifestyle       73.56        10   36.7800
# 4         Health and beauty       36.26         2    3.6260
# ..                      ...         ...       ...       ...
# 995  Electronic accessories       58.03         2    5.8030
# 996     Fashion accessories       17.49        10    8.7450
# 997       Health and beauty       40.35         1    2.0175
# 998      Food and beverages       31.84         1    1.5920
# 999      Home and lifestyle       65.82         1    3.2910
#
# [1000 rows x 9 columns]

# %%
df.head()
# Out:
#    Gender   Invoice ID Branch       City Customer type  \
# 0  Female  750-67-8428      A     Yangon        Member
# 1  Female  226-31-3081      C  Naypyitaw        Normal
# 2  Female  355-53-5943      A     Yangon        Member
# 3  Female  315-22-5665      C  Naypyitaw        Normal
# 4  Female  665-32-9167      A     Yangon        Member
#
#              Product line  Unit price  Quantity   Tax 5%
# 0       Health and beauty       74.69         7  261.415
# 1  Electronic accessories       15.28         5    3.820
# 2  Electronic accessories       68.84         6   20.652
# 3      Home and lifestyle       73.56        10   36.780
# 4       Health and beauty       36.26         2    3.626

# %%
df.tail()
# Out:
#     Gender   Invoice ID Branch       City Customer type  \
# 995   Male  745-74-0715      A     Yangon        Normal
# 996   Male  690-01-6631      B   Mandalay        Normal
# 997   Male  233-67-5758      C  Naypyitaw        Normal
# 998   Male  727-02-1313      A     Yangon        Member
# 999   Male  347-56-2442      A     Yangon        Normal
#
#                Product line  Unit price  Quantity  Tax 5%
# 995  Electronic accessories       58.03         2  5.8030
# 996     Fashion accessories       17.49        10  8.7450
# 997       Health and beauty       40.35         1  2.0175
# 998      Food and beverages       31.84         1  1.5920
# 999      Home and lifestyle       65.82         1  3.2910

# %%
# Check for missing values
print(df.isnull().sum())

# Drop rows with missing values
df.dropna(inplace=True)
# Out:
# Gender           0
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Product line     0
# Unit price       0
# Quantity         0
# Tax 5%           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gender         1000 non-null   object
#  1   Invoice ID     1000 non-null   object
#  2   Branch         1000 non-null   object
#  3   City           1000 non-null   object
#  4   Customer type  1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Tax 5%         1000 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Gender           0
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Product line     0
# Unit price       0
# Quantity         0
# Tax 5%           0
# dtype: int64

# %%
df.drop(columns=["Gender"])
# Out:
#       Invoice ID Branch       City Customer type            Product line  \
# 0    750-67-8428      A     Yangon        Member       Health and beauty
# 1    226-31-3081      C  Naypyitaw        Normal  Electronic accessories
# 2    355-53-5943      A     Yangon        Member  Electronic accessories
# 3    315-22-5665      C  Naypyitaw        Normal      Home and lifestyle
# 4    665-32-9167      A     Yangon        Member       Health and beauty
# ..           ...    ...        ...           ...                     ...
# 995  745-74-0715      A     Yangon        Normal  Electronic accessories
# 996  690-01-6631      B   Mandalay        Normal     Fashion accessories
# 997  233-67-5758      C  Naypyitaw        Normal       Health and beauty
# 998  727-02-1313      A     Yangon        Member      Food and beverages
# 999  347-56-2442      A     Yangon        Normal      Home and lifestyle
#
#      Unit price  Quantity    Tax 5%
# 0         74.69         7  261.4150
# 1         15.28         5    3.8200
# 2         68.84         6   20.6520
# 3         73.56        10   36.7800
# 4         36.26         2    3.6260
# ..          ...       ...       ...
# 995       58.03         2    5.8030
# 996       17.49        10    8.7450
# 997       40.35         1    2.0175
# 998       31.84         1    1.5920
# 999       65.82         1    3.2910
#
# [1000 rows x 8 columns]

# %%
df.size
# Out:
# 9000

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%
# count  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    43.911392
# std      26.494628     2.923431   100.551612
# min      10.080000     1.000000     1.066000
# 25%      32.875000     3.000000     6.222500
# 50%      55.230000     5.000000    12.404000
# 75%      77.935000     8.000000    27.226250
# max      99.960000    10.000000   985.000000

# %%
df.dtypes
# Out:
# Gender            object
# Invoice ID        object
# Branch            object
# City              object
# Customer type     object
# Product line      object
# Unit price       float64
# Quantity           int64
# Tax 5%           float64
# dtype: object

# %%
df.describe().T.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.describe(include = 'all').T
# Out:
#                 count unique                  top freq       mean         std  \
# Gender           1000      2               Female  501        NaN         NaN
# Invoice ID       1000   1000          750-67-8428    1        NaN         NaN
# Branch           1000      3                    A  340        NaN         NaN
# City             1000      3               Yangon  340        NaN         NaN
# Customer type    1000      2               Member  501        NaN         NaN
# Product line     1000      6  Fashion accessories  178        NaN         NaN
# Unit price     1000.0    NaN                  NaN  NaN   55.67213   26.494628
# Quantity       1000.0    NaN                  NaN  NaN       5.51    2.923431
# Tax 5%         1000.0    NaN                  NaN  NaN  43.911392  100.551612
#
#                  min     25%     50%       75%    max
# Gender           NaN     NaN     NaN       NaN    NaN
# Invoice ID       NaN     NaN     NaN       NaN    NaN
# Branch           NaN     NaN     NaN       NaN    NaN
# City             NaN     NaN     NaN       NaN    NaN
# Customer type    NaN     NaN     NaN       NaN    NaN
# Product line     NaN     NaN     NaN       NaN    NaN
# Unit price     10.08  32.875   55.23    77.935  99.96
# Quantity         1.0     3.0     5.0       8.0   10.0
# Tax 5%         1.066  6.2225  12.404  27.22625  985.0
